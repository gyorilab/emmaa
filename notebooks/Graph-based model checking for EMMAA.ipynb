# %% [markdown]
# # Graph-Based Model Checking for EMMAA

# %% [markdown]
# This notebook explores the ut

# %%
import json
import pickle
from collections import defaultdict
import boto3
import pandas as pd
import networkx as nx
from indra.statements import *
from emmaa.util import get_s3_client

# %%
pd.set_option('display.max_rows', 500)

# %% [markdown]
# Load the latest model manager and test results JSON for the EMMAA Ras Machine model:

# %%
s3 = get_s3_client()
# Get the Model Manager containing the assembled INDRA Statements
s3_obj = s3.get_object(Bucket='emmaa', Key='results/rasmachine/latest_model_manager.pkl')
mm = pickle.loads(s3_obj['Body'].read())
# Get the Test results JSON
s3_obj = s3.get_object(Bucket='emmaa', Key='results/rasmachine/results_2019-04-30-17-51-24.json')
res = json.load(s3_obj['Body'])

# %% [markdown]
# Get the assembled statements from the Model Manager and build a NetworkX DiGraph based on agent names:

# %%
stmts = mm.model.assembled_stmts
len(stmts)
# Out:
# 5453

# %%
edges = []
provenance = defaultdict(list)
for stmt in stmts:
    if not len(stmt.agent_list()) == 2:
        continue
    subj, obj = stmt.agent_list()
    edges.append((subj.name, obj.name))
    if isinstance(stmt, Complex):
        edges.append((obj.name, subj.name))
    provenance[(subj.name, obj.name)].append(stmt)
g = nx.DiGraph()
g.add_edges_from(edges)

# %% [markdown]
# Get the tests and results from the result JSON and compile a list of (source, target) test pairs along with results obtained from the ModelChecker:

# %%
g_tests = []
for result in res[1:]:
    code = result['result_json']['result_code']
    if result['english_path']:
        mc_path_len = len(result['english_path'][0])
    else:
        mc_path_len = 0
    tj = result['test_json']
    test_stmt = stmts_from_json([tj])[0]
    if len(test_stmt.agent_list()) == 2:
        subj, obj = test_stmt.agent_list()
        if subj.name != obj.name:
            g_tests.append((tj['type'], subj.name, obj.name, code, mc_path_len))

# %% [markdown]
# Using the directed graph compiled from the model statements we look for shortest paths connecting the pairs of test nodes and build a Pandas DataFrame with the results:

# %%
rows = []
for stmt_type, subj, obj, code, mc_path_len in g_tests:
    sp_text = ''
    g_path_len = 0
    if subj not in g:
        g_code = 'SUBJECT_NODE_NOT_FOUND'
    elif obj not in g:
        g_code = 'OBJECT_NODE_NOT_FOUND'
    else:
        g_code = 'PATH_FOUND'
        try:
            sp = nx.shortest_path(g, subj, obj)
            g_path_len = len(sp) - 1
            sp_text = ' -> '.join(sp)
        except nx.NetworkXNoPath:
            g_code = 'NO_PATH'
    rows.append((stmt_type, subj, obj, code, mc_path_len, g_code, g_path_len, sp_text))
df = pd.DataFrame.from_records(rows, columns=['test_stmt_type', 'subj', 'obj', 'mc_code',
                                              'mc_path_len', 'g_code', 'g_path_len', 'shortest_path'])

# %% [markdown]
# Let's look at some statistics from the results. First, the cases where both the ModelChecker and the Graph found a path:

# %%
both_path = df[(df.mc_code == 'PATHS_FOUND') & (df.g_code == 'PATH_FOUND')]

# %%
print("Number of MC tests passed: %d" % len(df[df.mc_code == 'PATHS_FOUND']))
print("Number of tests passed by both MC and G: %d" % len(both_path))
both_path
# Out:
# Number of MC tests passed: 117
# Number of tests passed by both MC and G: 117
#       test_stmt_type     subj       obj      mc_code  mc_path_len      g_code  \
# 0         Activation     AKT1      MTOR  PATHS_FOUND            1  PATH_FOUND
# 2         Activation     AKT1   RPS6KB2  PATHS_FOUND            2  PATH_FOUND
# 15        Activation     BRAF      ELK1  PATHS_FOUND            2  PATH_FOUND
# 17        Activation     BRAF     MAPK1  PATHS_FOUND            1  PATH_FOUND
# 18        Activation     BRAF     MAPK3  PATHS_FOUND            1  PATH_FOUND
# 21        Activation    CASP8     CASP3  PATHS_FOUND            1  PATH_FOUND
# 31        Activation     CDK2    PPP1CA  PATHS_FOUND            1  PATH_FOUND
# 48        Activation     E2F1      TP53  PATHS_FOUND            3  PATH_FOUND
# 58        Activation     EGFR     ERBB2  PATHS_FOUND            1  PATH_FOUND
# 60        Activation     EGFR      HRAS  PATHS_FOUND            2  PATH_FOUND
# 61        Activation     EGFR      IRS1  PATHS_FOUND            1  PATH_FOUND
# 94        Activation    ERBB2      HRAS  PATHS_FOUND            1  PATH_FOUND
# 102       Activation    ERBB2      GRB2  PATHS_FOUND            1  PATH_FOUND
# 138       Activation     HRAS     MAPK1  PATHS_FOUND            3  PATH_FOUND
# 139       Activation     HRAS      ETS1  PATHS_FOUND            4  PATH_FOUND
# 140       Activation     HRAS      ETS2  PATHS_FOUND            4  PATH_FOUND
# 141       Activation     HRAS     MAPK3  PATHS_FOUND            3  PATH_FOUND
# 155       Activation     IRS1    PIK3R1  PATHS_FOUND            1  PATH_FOUND
# 166       Activation     KRAS     MAPK1  PATHS_FOUND            3  PATH_FOUND
# 169       Activation   MAP2K1   RPS6KA1  PATHS_FOUND            2  PATH_FOUND
# 171       Activation   MAP2K1    MAP2K2  PATHS_FOUND            2  PATH_FOUND
# 172       Activation   MAP2K2      ELK1  PATHS_FOUND            2  PATH_FOUND
# 178       Activation    MAPK1      ETS1  PATHS_FOUND            1  PATH_FOUND
# 179       Activation    MAPK1       MYC  PATHS_FOUND            1  PATH_FOUND
# 180       Activation    MAPK1   RPS6KA1  PATHS_FOUND            1  PATH_FOUND
# 182       Activation    MAPK1   RPS6KA3  PATHS_FOUND            2  PATH_FOUND
# 188       Activation    MAPK3      ETS1  PATHS_FOUND            1  PATH_FOUND
# 189       Activation    MAPK3       MYC  PATHS_FOUND            1  PATH_FOUND
# 190       Activation    MAPK3   RPS6KA1  PATHS_FOUND            1  PATH_FOUND
# 191       Activation    MAPK3   RPS6KA3  PATHS_FOUND            1  PATH_FOUND
# 211       Activation     NRAS     MAPK1  PATHS_FOUND            3  PATH_FOUND
# 212       Activation     NRAS     MAPK3  PATHS_FOUND            3  PATH_FOUND
# 213       Activation     PAK1    MAP2K1  PATHS_FOUND            2  PATH_FOUND
# 214       Activation     PAK1    MAP2K2  PATHS_FOUND            3  PATH_FOUND
# 215       Activation     PAK1     MAPK1  PATHS_FOUND            3  PATH_FOUND
# 216       Activation     PAK1     MAPK3  PATHS_FOUND            3  PATH_FOUND
# 229       Activation   PIK3CG      AKT1  PATHS_FOUND            2  PATH_FOUND
# 230       Activation   PIK3R1      AKT1  PATHS_FOUND            1  PATH_FOUND
# 240       Activation   PTPN11      EGFR  PATHS_FOUND            2  PATH_FOUND
# 255       Activation     RAF1    MAP2K2  PATHS_FOUND            1  PATH_FOUND
# 257       Activation     RAF1      ETS1  PATHS_FOUND            3  PATH_FOUND
# 258       Activation     RAF1      ETS2  PATHS_FOUND            2  PATH_FOUND
# 259       Activation     RAF1     MAPK1  PATHS_FOUND            2  PATH_FOUND
# 261       Activation     RAF1     MAPK1  PATHS_FOUND            2  PATH_FOUND
# 262       Activation     RAF1     MAPK3  PATHS_FOUND            1  PATH_FOUND
# 264       Activation  RASGRF1      HRAS  PATHS_FOUND            1  PATH_FOUND
# 278       Activation     RHOC     ROCK1  PATHS_FOUND            1  PATH_FOUND
# 280       Activation  RPS6KA2       FOS  PATHS_FOUND            1  PATH_FOUND
# 281       Activation  RPS6KA2       JUN  PATHS_FOUND            3  PATH_FOUND
# 288       Activation     SHC1      RAC1  PATHS_FOUND            2  PATH_FOUND
# 296       Activation      SRC      EGFR  PATHS_FOUND            2  PATH_FOUND
# 306       Activation    STK11      TP53  PATHS_FOUND            4  PATH_FOUND
# 307       Activation    STK11      TSC2  PATHS_FOUND            4  PATH_FOUND
# 310       Activation    TIAM1      RAC1  PATHS_FOUND            1  PATH_FOUND
# 318       Activation     VAV1       CBL  PATHS_FOUND            1  PATH_FOUND
# 321       Activation     YAP1      TP73  PATHS_FOUND            1  PATH_FOUND
# 417   DecreaseAmount      RB1      E2F3  PATHS_FOUND            4  PATH_FOUND
# 453   IncreaseAmount     E2F1      TP53  PATHS_FOUND            2  PATH_FOUND
# 475   IncreaseAmount     ETS2       MYC  PATHS_FOUND            3  PATH_FOUND
# 490   IncreaseAmount      JUN      TP73  PATHS_FOUND            4  PATH_FOUND
# 491   IncreaseAmount      JUN       FOS  PATHS_FOUND            1  PATH_FOUND
# 494   IncreaseAmount   MAP2K2       MYC  PATHS_FOUND            2  PATH_FOUND
# 496   IncreaseAmount    MAPK1    CDKN1A  PATHS_FOUND            2  PATH_FOUND
# 498   IncreaseAmount    MAPK3       MYC  PATHS_FOUND            2  PATH_FOUND
# 505   IncreaseAmount     MTOR     CCND1  PATHS_FOUND            2  PATH_FOUND
# 506   IncreaseAmount     MTOR      MDM2  PATHS_FOUND            2  PATH_FOUND
# 507   IncreaseAmount     MTOR       MYC  PATHS_FOUND            2  PATH_FOUND
# 508   IncreaseAmount      MYC    CDC25A  PATHS_FOUND            3  PATH_FOUND
# 510   IncreaseAmount      MYC     CCND2  PATHS_FOUND            1  PATH_FOUND
# 515   IncreaseAmount     RAF1       JUN  PATHS_FOUND            3  PATH_FOUND
# 517   IncreaseAmount     RAF1     RASA3  PATHS_FOUND            3  PATH_FOUND
# 519   IncreaseAmount      RB1     CCND3  PATHS_FOUND            2  PATH_FOUND
# 520   IncreaseAmount      RB1      CDC6  PATHS_FOUND            2  PATH_FOUND
# 522   IncreaseAmount  RPS6KB1       RB1  PATHS_FOUND            3  PATH_FOUND
# 540   IncreaseAmount     TP53    CDKN1A  PATHS_FOUND            1  PATH_FOUND
# 557       Inhibition     AKT1      TP73  PATHS_FOUND            4  PATH_FOUND
# 583       Inhibition    CCNA1      CDK2  PATHS_FOUND            2  PATH_FOUND
# 587       Inhibition     CDK4       RB1  PATHS_FOUND            2  PATH_FOUND
# 591       Inhibition   CDKN1A      CDK2  PATHS_FOUND            2  PATH_FOUND
# 595       Inhibition    DUSP1     MAPK1  PATHS_FOUND            1  PATH_FOUND
# 599       Inhibition    DUSP3     MAPK3  PATHS_FOUND            1  PATH_FOUND
# 616       Inhibition    MAPK1      SOS1  PATHS_FOUND            4  PATH_FOUND
# 621       Inhibition      MYC      MDM2  PATHS_FOUND            3  PATH_FOUND
# 667       Inhibition    STK11      MTOR  PATHS_FOUND            4  PATH_FOUND
# 673       Inhibition     TP53     CASP8  PATHS_FOUND            3  PATH_FOUND
# 675       Inhibition     TP53      HRAS  PATHS_FOUND            2  PATH_FOUND
# 688  Phosphorylation     AKT1      MDM2  PATHS_FOUND            1  PATH_FOUND
# 689  Phosphorylation     AKT1      MTOR  PATHS_FOUND            1  PATH_FOUND
# 690  Phosphorylation     AKT1   RPS6KB1  PATHS_FOUND            2  PATH_FOUND
# 701  Phosphorylation    CCND1       RB1  PATHS_FOUND            4  PATH_FOUND
# 702  Phosphorylation    CCND2       RB1  PATHS_FOUND            4  PATH_FOUND
# 703  Phosphorylation    CCND3       RB1  PATHS_FOUND            2  PATH_FOUND
# 725  Phosphorylation     EGFR     MAPK3  PATHS_FOUND            1  PATH_FOUND
# 726  Phosphorylation     EGFR      RAF1  PATHS_FOUND            1  PATH_FOUND
# 728  Phosphorylation    ERBB2    PLXNB1  PATHS_FOUND            1  PATH_FOUND
# 747  Phosphorylation     HRAS     MAPK1  PATHS_FOUND            3  PATH_FOUND
# 748  Phosphorylation     HRAS     MAPK3  PATHS_FOUND            3  PATH_FOUND
# 750  Phosphorylation     HRAS       ERF  PATHS_FOUND            4  PATH_FOUND
# 753  Phosphorylation     HRAS     MAPK1  PATHS_FOUND            3  PATH_FOUND
# 771  Phosphorylation   MAP2K1     MAPK3  PATHS_FOUND            3  PATH_FOUND
# 776  Phosphorylation   MAP2K2     MAPK1  PATHS_FOUND            1  PATH_FOUND
# 787  Phosphorylation    MAPK1   RPS6KA3  PATHS_FOUND            1  PATH_FOUND
# 790  Phosphorylation    MAPK3      IRS1  PATHS_FOUND            2  PATH_FOUND
# 803  Phosphorylation     MTOR      AKT1  PATHS_FOUND            4  PATH_FOUND
# 804  Phosphorylation     MTOR  EIF4EBP1  PATHS_FOUND            1  PATH_FOUND
# 806  Phosphorylation     MTOR      IRS1  PATHS_FOUND            1  PATH_FOUND
# 809  Phosphorylation      MYC       RB1  PATHS_FOUND            2  PATH_FOUND
# 832  Phosphorylation     RAF1       ERF  PATHS_FOUND            3  PATH_FOUND
# 833  Phosphorylation     RAF1    MAP2K1  PATHS_FOUND            1  PATH_FOUND
# 834  Phosphorylation     RAF1    MAP2K2  PATHS_FOUND            1  PATH_FOUND
# 835  Phosphorylation     RAF1     MAPK1  PATHS_FOUND            2  PATH_FOUND
# 836  Phosphorylation     RAF1     MAPK1  PATHS_FOUND            2  PATH_FOUND
# 837  Phosphorylation     RAF1     MAPK3  PATHS_FOUND            2  PATH_FOUND
# 846  Phosphorylation  RPS6KB1      IRS1  PATHS_FOUND            1  PATH_FOUND
# 847  Phosphorylation      SRC       CBL  PATHS_FOUND            2  PATH_FOUND
# 849  Phosphorylation      SRC      EGFR  PATHS_FOUND            2  PATH_FOUND
# 858  Phosphorylation    STK11      TP53  PATHS_FOUND            3  PATH_FOUND
#
#      g_path_len                   shortest_path
# 0             1                    AKT1 -> MTOR
# 2             1                 AKT1 -> RPS6KB2
# 15            2           BRAF -> MAPK1 -> ELK1
# 17            1                   BRAF -> MAPK1
# 18            1                   BRAF -> MAPK3
# 21            1                  CASP8 -> CASP3
# 31            1                  CDK2 -> PPP1CA
# 48            1                    E2F1 -> TP53
# 58            1                   EGFR -> ERBB2
# 60            1                    EGFR -> HRAS
# 61            1                    EGFR -> IRS1
# 94            1                   ERBB2 -> HRAS
# 102           1                   ERBB2 -> GRB2
# 138           2         HRAS -> MAP2K1 -> MAPK1
# 139           2           HRAS -> ERBB2 -> ETS1
# 140           2            HRAS -> INSR -> ETS2
# 141           2         HRAS -> MAP2K1 -> MAPK3
# 155           1                  IRS1 -> PIK3R1
# 166           1                   KRAS -> MAPK1
# 169           2       MAP2K1 -> TP53 -> RPS6KA1
# 171           1                MAP2K1 -> MAP2K2
# 172           2         MAP2K2 -> MAPK1 -> ELK1
# 178           1                   MAPK1 -> ETS1
# 179           1                    MAPK1 -> MYC
# 180           1                MAPK1 -> RPS6KA1
# 182           1                MAPK1 -> RPS6KA3
# 188           1                   MAPK3 -> ETS1
# 189           1                    MAPK3 -> MYC
# 190           1                MAPK3 -> RPS6KA1
# 191           1                MAPK3 -> RPS6KA3
# 211           2           NRAS -> BRAF -> MAPK1
# 212           2           NRAS -> BRAF -> MAPK3
# 213           1                  PAK1 -> MAP2K1
# 214           2          PAK1 -> ARAF -> MAP2K2
# 215           1                   PAK1 -> MAPK1
# 216           2         PAK1 -> MAP2K1 -> MAPK3
# 229           2         PIK3CG -> PDPK1 -> AKT1
# 230           1                  PIK3R1 -> AKT1
# 240           1                  PTPN11 -> EGFR
# 255           1                  RAF1 -> MAP2K2
# 257           2           RAF1 -> MAPK1 -> ETS1
# 258           2           RAF1 -> MAPK3 -> ETS2
# 259           1                   RAF1 -> MAPK1
# 261           1                   RAF1 -> MAPK1
# 262           1                   RAF1 -> MAPK3
# 264           1                 RASGRF1 -> HRAS
# 278           1                   RHOC -> ROCK1
# 280           1                  RPS6KA2 -> FOS
# 281           1                  RPS6KA2 -> JUN
# 288           2            SHC1 -> GRB2 -> RAC1
# 296           1                     SRC -> EGFR
# 306           1                   STK11 -> TP53
# 307           1                   STK11 -> TSC2
# 310           1                   TIAM1 -> RAC1
# 318           1                     VAV1 -> CBL
# 321           1                    YAP1 -> TP73
# 417           1                     RB1 -> E2F3
# 453           1                    E2F1 -> TP53
# 475           1                     ETS2 -> MYC
# 490           2           JUN -> RALBP1 -> TP73
# 491           1                      JUN -> FOS
# 494           2           MAP2K2 -> BRAF -> MYC
# 496           1                 MAPK1 -> CDKN1A
# 498           1                    MAPK3 -> MYC
# 505           2         MTOR -> CDKN1A -> CCND1
# 506           1                    MTOR -> MDM2
# 507           1                     MTOR -> MYC
# 508           1                   MYC -> CDC25A
# 510           1                    MYC -> CCND2
# 515           2             RAF1 -> HRAS -> JUN
# 517           3  RAF1 -> MAPK3 -> ETS2 -> RASA3
# 519           1                    RB1 -> CCND3
# 520           1                     RB1 -> CDC6
# 522           2           RPS6KB1 -> FOS -> RB1
# 540           1                  TP53 -> CDKN1A
# 557           2           AKT1 -> BRCA1 -> TP73
# 583           1                   CCNA1 -> CDK2
# 587           1                     CDK4 -> RB1
# 591           1                  CDKN1A -> CDK2
# 595           1                  DUSP1 -> MAPK1
# 599           1                  DUSP3 -> MAPK3
# 616           1                   MAPK1 -> SOS1
# 621           2             MYC -> TP53 -> MDM2
# 667           1                   STK11 -> MTOR
# 673           1                   TP53 -> CASP8
# 675           1                    TP53 -> HRAS
# 688           1                    AKT1 -> MDM2
# 689           1                    AKT1 -> MTOR
# 690           1                 AKT1 -> RPS6KB1
# 701           1                    CCND1 -> RB1
# 702           1                    CCND2 -> RB1
# 703           1                    CCND3 -> RB1
# 725           1                   EGFR -> MAPK3
# 726           1                    EGFR -> RAF1
# 728           1                 ERBB2 -> PLXNB1
# 747           2         HRAS -> MAP2K1 -> MAPK1
# 748           2         HRAS -> MAP2K1 -> MAPK3
# 750           3  HRAS -> MAP2K1 -> MAPK1 -> ERF
# 753           2         HRAS -> MAP2K1 -> MAPK1
# 771           1                 MAP2K1 -> MAPK3
# 776           1                 MAP2K2 -> MAPK1
# 787           1                MAPK1 -> RPS6KA3
# 790           1                   MAPK3 -> IRS1
# 803           1                    MTOR -> AKT1
# 804           1                MTOR -> EIF4EBP1
# 806           1                    MTOR -> IRS1
# 809           1                      MYC -> RB1
# 832           2            RAF1 -> MAPK1 -> ERF
# 833           1                  RAF1 -> MAP2K1
# 834           1                  RAF1 -> MAP2K2
# 835           1                   RAF1 -> MAPK1
# 836           1                   RAF1 -> MAPK1
# 837           1                   RAF1 -> MAPK3
# 846           1                 RPS6KB1 -> IRS1
# 847           2              SRC -> EGFR -> CBL
# 849           1                     SRC -> EGFR
# 858           1                   STK11 -> TP53

# %% [markdown]
# Does it ever happen that the ModelChecker finds a path where there is none in the graph? Apparently not, which is reassuring because the paths found by the ModelChecker should be a strict subset of those in the directed graph:

# %%
df[(df.mc_code == 'PATHS_FOUND') & (df.g_code != 'PATH_FOUND')]
# Out:
# Empty DataFrame
# Columns: [stmt_type, subj, obj, mc_code, mc_path_len, g_code, shortest_path]
# Index: []

# %% [markdown]
# As an additional sanity check, we look for cases where the ModelChecker yields a *shorter* path than the shortest path in the graph, which should not happen (and doesn't):

# %%
df[(df.mc_code == 'PATHS_FOUND') & (df.mc_path_len < df.g_path_len)]
# Out:
# Empty DataFrame
# Columns: [test_stmt_type, subj, obj, mc_code, mc_path_len, g_code, g_path_len, shortest_path]
# Index: []

# %% [markdown]
# Next, how often is it that tests failed by the ModelChecker are passed in the Graph:

# %%
g_only_path = df[(df.mc_code != 'PATHS_FOUND') & (df.g_code == 'PATH_FOUND')]
mc_fail = len(df[df.mc_code != 'PATHS_FOUND'])
g_only = len(g_only_path)
ratio = g_only / mc_fail
print("Number of MC tests failed: %d" % mc_fail)
print("Number of tests failed by MC and passed by G: %d" % g_only)
print("Ratio: %.3f" % ratio)
g_only_path
# Out:
# Number of MC tests failed: 750
# Number of tests failed by MC and passed by G: 392
# Ratio: 0.523
#            stmt_type        subj       obj                     mc_code  \
# 16        Activation        BRAF       ERK              NO_PATHS_FOUND
# 22        Activation       CASP8     NFKB1              NO_PATHS_FOUND
# 28        Activation        CD28       AKT       OBSERVABLES_NOT_FOUND
# 30        Activation        CDK2       E2F              NO_PATHS_FOUND
# 32        Activation        CDK4       E2F              NO_PATHS_FOUND
# 34        Activation        CDK6       E2F              NO_PATHS_FOUND
# 36        Activation      CDKN1A      PAK1              NO_PATHS_FOUND
# 56        Activation        EGFR       AKT       OBSERVABLES_NOT_FOUND
# 57        Activation        EGFR      ELK1              NO_PATHS_FOUND
# 59        Activation        EGFR       ERK              NO_PATHS_FOUND
# 62        Activation        EGFR       JUN              NO_PATHS_FOUND
# 64        Activation        EGFR     MAPK1              NO_PATHS_FOUND
# 65        Activation        EGFR     MAPK3              NO_PATHS_FOUND
# 66        Activation        EGFR       MET              NO_PATHS_FOUND
# 67        Activation        EGFR      NRAS              NO_PATHS_FOUND
# 68        Activation        EGFR     PLCE1       OBSERVABLES_NOT_FOUND
# 69        Activation        EGFR      RAC1              NO_PATHS_FOUND
# 70        Activation        EGFR      RAF1              NO_PATHS_FOUND
# 71        Activation        EGFR   RASGRP3              NO_PATHS_FOUND
# 76        Activation        EGFR       AKT       OBSERVABLES_NOT_FOUND
# 78        Activation        EGFR       AKT       OBSERVABLES_NOT_FOUND
# 79        Activation        EGFR     MAPK1              NO_PATHS_FOUND
# 80        Activation        EGFR      AKT1              NO_PATHS_FOUND
# 85        Activation       EP300      TP63       OBSERVABLES_NOT_FOUND
# 91        Activation       ERBB2       AKT       OBSERVABLES_NOT_FOUND
# 93        Activation       ERBB2       ERK              NO_PATHS_FOUND
# 95        Activation       ERBB2     MAPK1              NO_PATHS_FOUND
# 96        Activation       ERBB2     MAPK3              NO_PATHS_FOUND
# 99        Activation       ERBB2      ETS2              NO_PATHS_FOUND
# 100       Activation       ERBB2      MDM2              NO_PATHS_FOUND
# 101       Activation       ERBB2       AKT       OBSERVABLES_NOT_FOUND
# 112       Activation  Everolimus     MAPK3  SUBJECT_MONOMERS_NOT_FOUND
# 113       Activation       FGFR1      AKT1              NO_PATHS_FOUND
# 114       Activation       FGFR1      AKT3              NO_PATHS_FOUND
# 115       Activation       FGFR1       ERK              NO_PATHS_FOUND
# 120       Activation        FLT3       AKT       OBSERVABLES_NOT_FOUND
# 124       Activation        GRB2       CBL              NO_PATHS_FOUND
# 125       Activation        GRB2     MAPK1              NO_PATHS_FOUND
# 126       Activation        GRB2     MAPK3              NO_PATHS_FOUND
# 127       Activation        GRB2     MAPK1              NO_PATHS_FOUND
# 128       Activation        GRB2     MAPK3              NO_PATHS_FOUND
# 129       Activation        GRB2     MAPK3              NO_PATHS_FOUND
# 130       Activation        GRB2      HRAS              NO_PATHS_FOUND
# 131       Activation        GRB2       ERK              NO_PATHS_FOUND
# 132       Activation        GRB2       ERK              NO_PATHS_FOUND
# 133       Activation        GRB2     MAPK1              NO_PATHS_FOUND
# 134       Activation        GRB2     MAPK3              NO_PATHS_FOUND
# 135       Activation        GRB2      RAF1              NO_PATHS_FOUND
# 142       Activation        HRAS     PLCE1       OBSERVABLES_NOT_FOUND
# 143       Activation        HRAS     ROCK1    MAX_PATH_LENGTH_EXCEEDED
# 145       Activation        INSR       AKT       OBSERVABLES_NOT_FOUND
# 146       Activation        INSR   RPS6KB1              NO_PATHS_FOUND
# 147       Activation        INSR       AKT       OBSERVABLES_NOT_FOUND
# 148       Activation        INSR     MAPK3              NO_PATHS_FOUND
# 149       Activation        INSR   RAPGEF1              NO_PATHS_FOUND
# 151       Activation        IRS1      HRAS              NO_PATHS_FOUND
# 152       Activation        IRS1       AKT       OBSERVABLES_NOT_FOUND
# 153       Activation        IRS1       ERK              NO_PATHS_FOUND
# 154       Activation        IRS1      HRAS              NO_PATHS_FOUND
# 156       Activation        IRS1    PTPN11              NO_PATHS_FOUND
# 167       Activation        KRAS    RASSF2       OBSERVABLES_NOT_FOUND
# 170       Activation      MAP2K1   RPS6KA2              NO_PATHS_FOUND
# 181       Activation       MAPK1   RPS6KA2              NO_PATHS_FOUND
# 183       Activation       MAPK1   RPS6KB2    MAX_PATH_LENGTH_EXCEEDED
# 192       Activation       MAPK3   RPS6KB2    MAX_PATH_LENGTH_EXCEEDED
# 197       Activation        MDM2      TP53              NO_PATHS_FOUND
# 198       Activation       MERTK     MAPK1              NO_PATHS_FOUND
# 199       Activation       MERTK     MAPK3              NO_PATHS_FOUND
# 200       Activation       MERTK      RAF1              NO_PATHS_FOUND
# 202       Activation         MET      RAC1              NO_PATHS_FOUND
# 208       Activation         MYC      CDK2    MAX_PATH_LENGTH_EXCEEDED
# 210       Activation        NRAS      AKT1    MAX_PATH_LENGTH_EXCEEDED
# 217       Activation        PAK1      RAF1    MAX_PATH_LENGTH_EXCEEDED
# 219       Activation        PAK4     MAPK1              NO_PATHS_FOUND
# 220       Activation        PAK4     MAPK3              NO_PATHS_FOUND
# 222       Activation      PDGFRB      HRAS              NO_PATHS_FOUND
# 223       Activation      PDGFRB       AKT       OBSERVABLES_NOT_FOUND
# 224       Activation      PDGFRB     MAPK3              NO_PATHS_FOUND
# 227       Activation       PDGFR      HRAS              NO_PATHS_FOUND
# 231       Activation        PIN1       JUN    MAX_PATH_LENGTH_EXCEEDED
# 232       Activation      PLXNB1      RHOA              NO_PATHS_FOUND
# 234       Activation      PLXNB1     ERBB2              NO_PATHS_FOUND
# 236       Activation        PTEN      TP53              NO_PATHS_FOUND
# 237       Activation        PTEN      TP53              NO_PATHS_FOUND
# 238       Activation      PTPN11     MAPK1  SUBJECT_MONOMERS_NOT_FOUND
# 239       Activation      PTPN11     MAPK1  SUBJECT_MONOMERS_NOT_FOUND
# 241       Activation      PTPN11       ERK              NO_PATHS_FOUND
# 242       Activation      PTPN11     MAPK1              NO_PATHS_FOUND
# 243       Activation      PTPN11     MAPK3              NO_PATHS_FOUND
# 244       Activation      PTPN11       AKT       OBSERVABLES_NOT_FOUND
# 245       Activation        RAC1      AKT3              NO_PATHS_FOUND
# 247       Activation        RAC1       JUN              NO_PATHS_FOUND
# 248       Activation        RAC1      PAK2              NO_PATHS_FOUND
# 249       Activation        RAC1   RPS6KB1              NO_PATHS_FOUND
# 251       Activation        RAC1      PAK1              NO_PATHS_FOUND
# 253       Activation        RAC2     MAPK1              NO_PATHS_FOUND
# 254       Activation        RAC2     MAPK3              NO_PATHS_FOUND
# 256       Activation        RAF1       ERK              NO_PATHS_FOUND
# 263       Activation     RASGRF1      HRAS              NO_PATHS_FOUND
# 266       Activation      RASSF1       ERK              NO_PATHS_FOUND
# 267       Activation      RASSF1     MAPK1              NO_PATHS_FOUND
# 268       Activation      RASSF1     MAPK3              NO_PATHS_FOUND
# 269       Activation         RB1       E2F              NO_PATHS_FOUND
# 270       Activation         RB1       E2F              NO_PATHS_FOUND
# 271       Activation        RHEB      MTOR              NO_PATHS_FOUND
# 272       Activation        RHEB   RPS6KB1              NO_PATHS_FOUND
# 274       Activation        RHOA     MAPK1              NO_PATHS_FOUND
# 276       Activation        RHOA     PLCE1       OBSERVABLES_NOT_FOUND
# 277       Activation        RHOB      AKT1              NO_PATHS_FOUND
# 283       Activation        SHC1     MAPK3              NO_PATHS_FOUND
# 286       Activation        SHC1      HRAS              NO_PATHS_FOUND
# 287       Activation        SHC1       ERK              NO_PATHS_FOUND
# 290       Activation        SOS1       ERK              NO_PATHS_FOUND
# 291       Activation        SOS1     MAPK1              NO_PATHS_FOUND
# 292       Activation        SOS1     MAPK3              NO_PATHS_FOUND
# 294       Activation         SRC      AKT1              NO_PATHS_FOUND
# 295       Activation         SRC       AKT       OBSERVABLES_NOT_FOUND
# 297       Activation         SRC      ETS2              NO_PATHS_FOUND
# 299       Activation         SRC    MAP2K2              NO_PATHS_FOUND
# 301       Activation         SRC       MYC              NO_PATHS_FOUND
# 302       Activation         SRC    PDGFRB              NO_PATHS_FOUND
# 303       Activation         SRC      RAC1              NO_PATHS_FOUND
# 309       Activation   Sirolimus       AKT  SUBJECT_MONOMERS_NOT_FOUND
# 311       Activation        TP53     CASP3    MAX_PATH_LENGTH_EXCEEDED
# 312       Activation        TSC2      BRAF              NO_PATHS_FOUND
# 313       Activation        TSC2     MAPK1              NO_PATHS_FOUND
# 314       Activation        TSC2     MAPK3              NO_PATHS_FOUND
# 315       Activation        TSC2      BRAF              NO_PATHS_FOUND
# 316       Activation        TSC2     MAPK1              NO_PATHS_FOUND
# 317       Activation        TSC2     MAPK3              NO_PATHS_FOUND
# 319       Activation        VAV1      PAK1              NO_PATHS_FOUND
# 320       Activation        VAV1      RAC2       OBSERVABLES_NOT_FOUND
# 323          Complex    ARHGAP35     RASA1  STATEMENT_TYPE_NOT_HANDLED
# 328          Complex         CBL      EGFR  STATEMENT_TYPE_NOT_HANDLED
# 329          Complex       CCND1      CDK4  STATEMENT_TYPE_NOT_HANDLED
# 330          Complex       CCND2      CDK4  STATEMENT_TYPE_NOT_HANDLED
# 334          Complex        E2F1       RB1  STATEMENT_TYPE_NOT_HANDLED
# 336          Complex        E2F1     TFDP1  STATEMENT_TYPE_NOT_HANDLED
# 337          Complex        E2F1     TFDP2  STATEMENT_TYPE_NOT_HANDLED
# 338          Complex        E2F2     TFDP1  STATEMENT_TYPE_NOT_HANDLED
# 339          Complex        E2F2     TFDP2  STATEMENT_TYPE_NOT_HANDLED
# 340          Complex        E2F3       RB1  STATEMENT_TYPE_NOT_HANDLED
# 341          Complex        EGFR     ERBB2  STATEMENT_TYPE_NOT_HANDLED
# 342          Complex        EGFR      IRS1  STATEMENT_TYPE_NOT_HANDLED
# 343          Complex        EGFR      SHC1  STATEMENT_TYPE_NOT_HANDLED
# 347          Complex       ERBB2    PTPN11  STATEMENT_TYPE_NOT_HANDLED
# 348          Complex       ERBB2      SHC1  STATEMENT_TYPE_NOT_HANDLED
# 350          Complex       FGFR2      PAK4  STATEMENT_TYPE_NOT_HANDLED
# 353          Complex         FOS       JUN  STATEMENT_TYPE_NOT_HANDLED
# 354          Complex        GRB2      IRS1  STATEMENT_TYPE_NOT_HANDLED
# 355          Complex        GRB2      IRS2  STATEMENT_TYPE_NOT_HANDLED
# 357          Complex        GRB2       MET  STATEMENT_TYPE_NOT_HANDLED
# 358          Complex        GRB2      PAK1  STATEMENT_TYPE_NOT_HANDLED
# 359          Complex        GRB2      SHC1  STATEMENT_TYPE_NOT_HANDLED
# 360          Complex        GRB2      SOS1  STATEMENT_TYPE_NOT_HANDLED
# 362          Complex        IRS1      MDM2  STATEMENT_TYPE_NOT_HANDLED
# 363          Complex        IRS1    PTPN11  STATEMENT_TYPE_NOT_HANDLED
# 364          Complex         JUN       RB1  STATEMENT_TYPE_NOT_HANDLED
# 366          Complex        KRAS    RASSF2  STATEMENT_TYPE_NOT_HANDLED
# 367          Complex      MAP2K1      RAF1  STATEMENT_TYPE_NOT_HANDLED
# 368          Complex        MDM2      TP53  STATEMENT_TYPE_NOT_HANDLED
# 371          Complex        PAK1      RAF1  STATEMENT_TYPE_NOT_HANDLED
# 372          Complex        PAK2      RAF1  STATEMENT_TYPE_NOT_HANDLED
# 373          Complex      PDGFRA    PDGFRB  STATEMENT_TYPE_NOT_HANDLED
# 375          Complex      PIK3R1    PTPN11  STATEMENT_TYPE_NOT_HANDLED
# 376          Complex        PTEN      TP53  STATEMENT_TYPE_NOT_HANDLED
# 377          Complex        RAF1       RB1  STATEMENT_TYPE_NOT_HANDLED
# 381          Complex        TP73      YAP1  STATEMENT_TYPE_NOT_HANDLED
# 382          Complex        TSC1      TSC2  STATEMENT_TYPE_NOT_HANDLED
# 383   DecreaseAmount        AKT1      TP53              NO_PATHS_FOUND
# 390   DecreaseAmount       BRCA1     BARD1              NO_PATHS_FOUND
# 391   DecreaseAmount       CASP3      MDM2              NO_PATHS_FOUND
# 392   DecreaseAmount         CBL      EGFR              NO_PATHS_FOUND
# 393   DecreaseAmount      CDC25A      CDK2              NO_PATHS_FOUND
# 395   DecreaseAmount         E2F     CCND1              NO_PATHS_FOUND
# 396   DecreaseAmount        EGFR      TP53              NO_PATHS_FOUND
# 405   DecreaseAmount        MDM2    CDKN1A              NO_PATHS_FOUND
# 406   DecreaseAmount        MTOR  EIF4EBP1              NO_PATHS_FOUND
# 407   DecreaseAmount         NF1     RASA1              NO_PATHS_FOUND
# 408   DecreaseAmount         NF1      TP53              NO_PATHS_FOUND
# 409   DecreaseAmount       PEA15       FOS              NO_PATHS_FOUND
# 410   DecreaseAmount        PTEN     CCND3              NO_PATHS_FOUND
# 411   DecreaseAmount        PTEN      GRB2              NO_PATHS_FOUND
# 412   DecreaseAmount        RAC2      RAC1              NO_PATHS_FOUND
# 413   DecreaseAmount        RAF1   RASGRP1              NO_PATHS_FOUND
# 414   DecreaseAmount      RASSF1     CCND1              NO_PATHS_FOUND
# 415   DecreaseAmount         RB1      E2F1    MAX_PATH_LENGTH_EXCEEDED
# 416   DecreaseAmount         RB1      E2F1    MAX_PATH_LENGTH_EXCEEDED
# 418   DecreaseAmount         RB1       JUN    MAX_PATH_LENGTH_EXCEEDED
# 419   DecreaseAmount         RB1      E2F2              NO_PATHS_FOUND
# 420   DecreaseAmount         RB1      E2F2              NO_PATHS_FOUND
# 421   DecreaseAmount       ROCK2       MYC              NO_PATHS_FOUND
# 424   DecreaseAmount   Sirolimus     CCND2  SUBJECT_MONOMERS_NOT_FOUND
# 425   DecreaseAmount   Sirolimus      MTOR  SUBJECT_MONOMERS_NOT_FOUND
# 426   DecreaseAmount   Sirolimus       MYC  SUBJECT_MONOMERS_NOT_FOUND
# 428   DecreaseAmount   Sirolimus    PIK3CG  SUBJECT_MONOMERS_NOT_FOUND
# 431   IncreaseAmount        AKT1      E2F1              NO_PATHS_FOUND
# 432   IncreaseAmount        AKT3     FOSL1              NO_PATHS_FOUND
# 444   IncreaseAmount        ARAF    MAP2K1    MAX_PATH_LENGTH_EXCEEDED
# 445   IncreaseAmount       BARD1      TP53              NO_PATHS_FOUND
# 446   IncreaseAmount         CBL      EGFR              NO_PATHS_FOUND
# 447   IncreaseAmount         CBL       MET              NO_PATHS_FOUND
# 454   IncreaseAmount         E2F       MYC              NO_PATHS_FOUND
# 457   IncreaseAmount        EGFR       FOS              NO_PATHS_FOUND
# 458   IncreaseAmount        EGFR      GRB2              NO_PATHS_FOUND
# 459   IncreaseAmount        EGFR   RPS6KA3              NO_PATHS_FOUND
# 460   IncreaseAmount        EGFR       AKT              NO_PATHS_FOUND
# 461   IncreaseAmount        EGFR     MAPK1              NO_PATHS_FOUND
# 462   IncreaseAmount        EGFR      GRB2              NO_PATHS_FOUND
# 463   IncreaseAmount        EGFR    PTPN11              NO_PATHS_FOUND
# 464   IncreaseAmount        EGFR      SHC1              NO_PATHS_FOUND
# 467   IncreaseAmount       ERBB2     CCND1              NO_PATHS_FOUND
# 468   IncreaseAmount       ERBB2      CDK2              NO_PATHS_FOUND
# 471   IncreaseAmount       ERBB2      AKT2              NO_PATHS_FOUND
# 472   IncreaseAmount       ERBB2     MAPK3              NO_PATHS_FOUND
# 473   IncreaseAmount       ERBB2   RPS6KB1              NO_PATHS_FOUND
# 478   IncreaseAmount        HRAS    CDKN1A    MAX_PATH_LENGTH_EXCEEDED
# 479   IncreaseAmount        HRAS    CDKN1A    MAX_PATH_LENGTH_EXCEEDED
# 480   IncreaseAmount        HRAS     PLCE1              NO_PATHS_FOUND
# 481   IncreaseAmount        HRAS     CCND1    MAX_PATH_LENGTH_EXCEEDED
# 483   IncreaseAmount        INSR       CBL              NO_PATHS_FOUND
# 493   IncreaseAmount        KRAS    CDKN1A    MAX_PATH_LENGTH_EXCEEDED
# 497   IncreaseAmount       MAPK1  EIF4EBP1              NO_PATHS_FOUND
# 500   IncreaseAmount        MDM2      TP53              NO_PATHS_FOUND
# 501   IncreaseAmount        MDM2      RAF1              NO_PATHS_FOUND
# 502   IncreaseAmount        MDM2      TP53              NO_PATHS_FOUND
# 504   IncreaseAmount         MET      MDM2              NO_PATHS_FOUND
# 516   IncreaseAmount        RAF1     RASA1              NO_PATHS_FOUND
# 518   IncreaseAmount        RAF1     SPRY2              NO_PATHS_FOUND
# 521   IncreaseAmount         RB1    RASSF2              NO_PATHS_FOUND
# 523   IncreaseAmount        SHC1      RAC1              NO_PATHS_FOUND
# 524   IncreaseAmount        SOS1      RAC1              NO_PATHS_FOUND
# 525   IncreaseAmount         SRC  ARHGAP35              NO_PATHS_FOUND
# 526   IncreaseAmount         SRC     CCND1              NO_PATHS_FOUND
# 528   IncreaseAmount         SRC      RAF1              NO_PATHS_FOUND
# 529   IncreaseAmount         SRC      EGFR              NO_PATHS_FOUND
# 530   IncreaseAmount         SRC     MAPK1              NO_PATHS_FOUND
# 531   IncreaseAmount         SRC     MAPK3              NO_PATHS_FOUND
# 532   IncreaseAmount         SRC      RAF1              NO_PATHS_FOUND
# 534   IncreaseAmount   Sirolimus    CDKN1A  SUBJECT_MONOMERS_NOT_FOUND
# 535   IncreaseAmount   Sirolimus       ERF  SUBJECT_MONOMERS_NOT_FOUND
# 536   IncreaseAmount   Sirolimus      INSR  SUBJECT_MONOMERS_NOT_FOUND
# 537   IncreaseAmount   Sirolimus    PIK3R1  SUBJECT_MONOMERS_NOT_FOUND
# 538   IncreaseAmount   Sirolimus      TP73  SUBJECT_MONOMERS_NOT_FOUND
# 539   IncreaseAmount   Sirolimus      TSC1  SUBJECT_MONOMERS_NOT_FOUND
# 556       Inhibition        AKT1      RAF1              NO_PATHS_FOUND
# 558       Inhibition        AKT1      TSC1              NO_PATHS_FOUND
# 559       Inhibition        AKT1      TSC2              NO_PATHS_FOUND
# 575       Inhibition       BRCA1       RB1    MAX_PATH_LENGTH_EXCEEDED
# 576       Inhibition       BRCA2      TP53              NO_PATHS_FOUND
# 577       Inhibition       BRCA2      TP53              NO_PATHS_FOUND
# 582       Inhibition         CBL      EGFR              NO_PATHS_FOUND
# 588       Inhibition      CDKN1A     CASP3              NO_PATHS_FOUND
# 589       Inhibition      CDKN1A     CASP8              NO_PATHS_FOUND
# 590       Inhibition      CDKN1A     CCND3              NO_PATHS_FOUND
# 593       Inhibition      DAB2IP      ELK1              NO_PATHS_FOUND
# 594       Inhibition       DUSP1       ERK              NO_PATHS_FOUND
# 596       Inhibition       DUSP1   RPS6KB1    MAX_PATH_LENGTH_EXCEEDED
# 598       Inhibition       DUSP3     MAPK1    MAX_PATH_LENGTH_EXCEEDED
# 602       Inhibition       DUSP6    MAP2K1    MAX_PATH_LENGTH_EXCEEDED
# 604       Inhibition        ESR2      CDK2              NO_PATHS_FOUND
# 608       Inhibition        HRAS      TSC2    MAX_PATH_LENGTH_EXCEEDED
# 611       Inhibition        IRS1      INSR              NO_PATHS_FOUND
# 612       Inhibition        IRS1      INSR              NO_PATHS_FOUND
# 613       Inhibition        IRS2      INSR              NO_PATHS_FOUND
# 617       Inhibition        MDM2      TP53              NO_PATHS_FOUND
# 618       Inhibition        MDM2       E2F              NO_PATHS_FOUND
# 619       Inhibition        MTOR       AKT       OBSERVABLES_NOT_FOUND
# 620       Inhibition        MTOR      IRS1    MAX_PATH_LENGTH_EXCEEDED
# 622       Inhibition         NF1       ERK              NO_PATHS_FOUND
# 624       Inhibition         NF1     MAPK1              NO_PATHS_FOUND
# 625       Inhibition         NF1     MAPK3              NO_PATHS_FOUND
# 626       Inhibition         NF1       RB1              NO_PATHS_FOUND
# 628       Inhibition       PEA15       FOS              NO_PATHS_FOUND
# 630       Inhibition        PTEN      AKT3              NO_PATHS_FOUND
# 631       Inhibition        PTEN       ERK              NO_PATHS_FOUND
# 632       Inhibition        PTEN      IRS1              NO_PATHS_FOUND
# 633       Inhibition        PTEN     MAPK1              NO_PATHS_FOUND
# 634       Inhibition        PTEN     MAPK3              NO_PATHS_FOUND
# 635       Inhibition        PTEN      MTOR              NO_PATHS_FOUND
# 636       Inhibition        PTEN     PDPK1              NO_PATHS_FOUND
# 637       Inhibition        PTEN      SHC1              NO_PATHS_FOUND
# 638       Inhibition        PTEN      AKT1              NO_PATHS_FOUND
# 639       Inhibition        PTEN       AKT       OBSERVABLES_NOT_FOUND
# 640       Inhibition        PTEN     MAPK3              NO_PATHS_FOUND
# 643       Inhibition        RAC1      TP53              NO_PATHS_FOUND
# 644       Inhibition        RAF1     MAPK1              NO_PATHS_FOUND
# 645       Inhibition        RAF1     MAPK3              NO_PATHS_FOUND
# 646       Inhibition         RB1      E2F1    MAX_PATH_LENGTH_EXCEEDED
# 647       Inhibition         RB1      E2F1    MAX_PATH_LENGTH_EXCEEDED
# 648       Inhibition         RB1      E2F1    MAX_PATH_LENGTH_EXCEEDED
# 649       Inhibition         RB1      E2F3    MAX_PATH_LENGTH_EXCEEDED
# 652       Inhibition         RB1      E2F1    MAX_PATH_LENGTH_EXCEEDED
# 653       Inhibition         RB1       E2F              NO_PATHS_FOUND
# 654       Inhibition        RHEB     MAPK3              NO_PATHS_FOUND
# 655       Inhibition       ROCK1    PPP1CA              NO_PATHS_FOUND
# 658       Inhibition     RPS6KB1      IRS1    MAX_PATH_LENGTH_EXCEEDED
# 662       Inhibition        SOS1      ETS1              NO_PATHS_FOUND
# 663       Inhibition       SPRY1       ERK              NO_PATHS_FOUND
# 671       Inhibition   Sirolimus   RPS6KB1  SUBJECT_MONOMERS_NOT_FOUND
# 672       Inhibition   Sirolimus      MTOR  SUBJECT_MONOMERS_NOT_FOUND
# 674       Inhibition        TP53       AKT       OBSERVABLES_NOT_FOUND
# 681       Inhibition        TSC1      MTOR              NO_PATHS_FOUND
# 682       Inhibition        TSC1   RPS6KB1              NO_PATHS_FOUND
# 684       Inhibition        TSC1      MTOR              NO_PATHS_FOUND
# 685       Inhibition        TSC2      MTOR              NO_PATHS_FOUND
# 686       Inhibition        TSC2   RPS6KB1              NO_PATHS_FOUND
# 687       Inhibition        TSC2   RPS6KB1              NO_PATHS_FOUND
# 704  Phosphorylation        CDK4       RB1    MAX_PATH_LENGTH_EXCEEDED
# 705  Phosphorylation      CDKN1A       RB1              NO_PATHS_FOUND
# 707  Phosphorylation       DUSP1     MAPK1    MAX_PATH_LENGTH_EXCEEDED
# 708  Phosphorylation       DUSP1     MAPK3    MAX_PATH_LENGTH_EXCEEDED
# 709  Phosphorylation       DUSP6     MAPK1    MAX_PATH_LENGTH_EXCEEDED
# 710  Phosphorylation        EGFR     ANXA1       OBSERVABLES_NOT_FOUND
# 713  Phosphorylation        EGFR       CBL       OBSERVABLES_NOT_FOUND
# 714  Phosphorylation        EGFR       CBL       OBSERVABLES_NOT_FOUND
# 715  Phosphorylation        EGFR     ERBB2              NO_PATHS_FOUND
# 716  Phosphorylation        EGFR      INSR              NO_PATHS_FOUND
# 717  Phosphorylation        EGFR       MET              NO_PATHS_FOUND
# 718  Phosphorylation        EGFR       MYC              NO_PATHS_FOUND
# 719  Phosphorylation        EGFR      SHC1              NO_PATHS_FOUND
# 720  Phosphorylation        EGFR      SHC1              NO_PATHS_FOUND
# 724  Phosphorylation        EGFR     ANXA1       OBSERVABLES_NOT_FOUND
# 729  Phosphorylation       ERBB2       RB1              NO_PATHS_FOUND
# 730  Phosphorylation       ERBB2      SHC1              NO_PATHS_FOUND
# 731  Phosphorylation       ERBB2      SHC1              NO_PATHS_FOUND
# 733  Phosphorylation       ERBB2     MAPK1              NO_PATHS_FOUND
# 734  Phosphorylation       ERBB2     MAPK3              NO_PATHS_FOUND
# 749  Phosphorylation        HRAS      BRAF    MAX_PATH_LENGTH_EXCEEDED
# 751  Phosphorylation        HRAS       JUN    MAX_PATH_LENGTH_EXCEEDED
# 752  Phosphorylation        HRAS       MYC    MAX_PATH_LENGTH_EXCEEDED
# 756  Phosphorylation        INSR    PTPN11              NO_PATHS_FOUND
# 757  Phosphorylation        INSR      SHC1              NO_PATHS_FOUND
# 758  Phosphorylation        IRS1      AKT1              NO_PATHS_FOUND
# 768  Phosphorylation        KRAS       RB1    MAX_PATH_LENGTH_EXCEEDED
# 769  Phosphorylation        KRAS   RPS6KB1    MAX_PATH_LENGTH_EXCEEDED
# 770  Phosphorylation        KRAS      ETS1    MAX_PATH_LENGTH_EXCEEDED
# 773  Phosphorylation      MAP2K1      ELK1    MAX_PATH_LENGTH_EXCEEDED
# 775  Phosphorylation      MAP2K2      ELK1    MAX_PATH_LENGTH_EXCEEDED
# 777  Phosphorylation      MAP2K2     MAPK1              NO_PATHS_FOUND
# 784  Phosphorylation       MAPK1     CCND1    MAX_PATH_LENGTH_EXCEEDED
# 785  Phosphorylation       MAPK1    CDC25A       OBSERVABLES_NOT_FOUND
# 786  Phosphorylation       MAPK1     DUSP1    MAX_PATH_LENGTH_EXCEEDED
# 789  Phosphorylation       MAPK3    CDC25A       OBSERVABLES_NOT_FOUND
# 794  Phosphorylation        MDM2      TP53              NO_PATHS_FOUND
# 795  Phosphorylation         MET      AKT1              NO_PATHS_FOUND
# 796  Phosphorylation         MET       CBL              NO_PATHS_FOUND
# 798  Phosphorylation         MET     MAPK1              NO_PATHS_FOUND
# 799  Phosphorylation         MET     MAPK3              NO_PATHS_FOUND
# 800  Phosphorylation         MET   RPS6KB1              NO_PATHS_FOUND
# 801  Phosphorylation         MET      SHC1              NO_PATHS_FOUND
# 805  Phosphorylation        MTOR  EIF4EBP1              NO_PATHS_FOUND
# 807  Phosphorylation        MTOR   RPS6KA1    MAX_PATH_LENGTH_EXCEEDED
# 808  Phosphorylation        MTOR   RPS6KB1    MAX_PATH_LENGTH_EXCEEDED
# 810  Phosphorylation         NF1      MDM2              NO_PATHS_FOUND
# 811  Phosphorylation         NF1       RB1              NO_PATHS_FOUND
# 812  Phosphorylation        NRAS   RPS6KB1    MAX_PATH_LENGTH_EXCEEDED
# 813  Phosphorylation        NRAS   RPS6KB1    MAX_PATH_LENGTH_EXCEEDED
# 814  Phosphorylation        NRAS   RPS6KB1    MAX_PATH_LENGTH_EXCEEDED
# 815  Phosphorylation      PDGFRB       AKT              NO_PATHS_FOUND
# 816  Phosphorylation        PTEN      AKT2              NO_PATHS_FOUND
# 817  Phosphorylation        PTEN       AKT              NO_PATHS_FOUND
# 818  Phosphorylation        PTEN      ETS2              NO_PATHS_FOUND
# 819  Phosphorylation        PTEN      IRS1              NO_PATHS_FOUND
# 820  Phosphorylation        PTEN      IRS2              NO_PATHS_FOUND
# 821  Phosphorylation        PTEN     MAPK1              NO_PATHS_FOUND
# 822  Phosphorylation        PTEN      SHC1              NO_PATHS_FOUND
# 823  Phosphorylation        PTEN       AKT              NO_PATHS_FOUND
# 824  Phosphorylation        PTEN      EGFR              NO_PATHS_FOUND
# 826  Phosphorylation      PTPN11      INSR              NO_PATHS_FOUND
# 827  Phosphorylation        RAC1      PAK1              NO_PATHS_FOUND
# 828  Phosphorylation        RAC1    PTPN11       OBSERVABLES_NOT_FOUND
# 830  Phosphorylation        RAC1     MAPK1              NO_PATHS_FOUND
# 838  Phosphorylation        RAF1       AKT              NO_PATHS_FOUND
# 839  Phosphorylation      RASSF1       AKT       OBSERVABLES_NOT_FOUND
# 840  Phosphorylation      RASSF1     MAPK1              NO_PATHS_FOUND
# 841  Phosphorylation      RASSF1     MAPK3              NO_PATHS_FOUND
# 842  Phosphorylation      RASSF1      RAF1              NO_PATHS_FOUND
# 843  Phosphorylation       ROCK1       MYC              NO_PATHS_FOUND
# 850  Phosphorylation         SRC    MAP2K1              NO_PATHS_FOUND
# 851  Phosphorylation         SRC    MAP2K2              NO_PATHS_FOUND
# 852  Phosphorylation         SRC     MAPK3              NO_PATHS_FOUND
# 853  Phosphorylation         SRC     PDGFR       OBSERVABLES_NOT_FOUND
# 855  Phosphorylation         SRC       AKT              NO_PATHS_FOUND
# 856  Phosphorylation         SRC     GRB10              NO_PATHS_FOUND
# 857  Phosphorylation         SRC     MAPK1              NO_PATHS_FOUND
# 859  Phosphorylation   Sirolimus       AKT  SUBJECT_MONOMERS_NOT_FOUND
# 860  Phosphorylation   Sirolimus  EIF4EBP1  SUBJECT_MONOMERS_NOT_FOUND
# 861  Phosphorylation   Sirolimus   RPS6KB1  SUBJECT_MONOMERS_NOT_FOUND
# 862  Phosphorylation   Sirolimus   RPS6KB1  SUBJECT_MONOMERS_NOT_FOUND
# 865  Phosphorylation        TP53  EIF4EBP1    MAX_PATH_LENGTH_EXCEEDED
# 866  Phosphorylation        VAV1       CBL              NO_PATHS_FOUND
#
#      mc_path_len      g_code                             shortest_path
# 16             0  PATH_FOUND                       BRAF -> ROS1 -> ERK
# 22             0  PATH_FOUND                   CASP8 -> MAPK1 -> NFKB1
# 28             0  PATH_FOUND       CD28 -> GRB2 -> ROS1 -> MTOR -> AKT
# 30             0  PATH_FOUND                       CDK2 -> CDK4 -> E2F
# 32             0  PATH_FOUND                               CDK4 -> E2F
# 34             0  PATH_FOUND                       CDK6 -> CDK4 -> E2F
# 36             0  PATH_FOUND                            CDKN1A -> PAK1
# 56             0  PATH_FOUND                       EGFR -> MTOR -> AKT
# 57             0  PATH_FOUND                     EGFR -> MAPK1 -> ELK1
# 59             0  PATH_FOUND                       EGFR -> ROS1 -> ERK
# 62             0  PATH_FOUND                               EGFR -> JUN
# 64             0  PATH_FOUND                             EGFR -> MAPK1
# 65             0  PATH_FOUND                             EGFR -> MAPK3
# 66             0  PATH_FOUND                               EGFR -> MET
# 67             0  PATH_FOUND                    EGFR -> PTPN11 -> NRAS
# 68             0  PATH_FOUND                     EGFR -> BRAF -> PLCE1
# 69             0  PATH_FOUND                      EGFR -> ROS1 -> RAC1
# 70             0  PATH_FOUND                              EGFR -> RAF1
# 71             0  PATH_FOUND                 EGFR -> PIK3CA -> RASGRP3
# 76             0  PATH_FOUND                       EGFR -> MTOR -> AKT
# 78             0  PATH_FOUND                       EGFR -> MTOR -> AKT
# 79             0  PATH_FOUND                             EGFR -> MAPK1
# 80             0  PATH_FOUND                              EGFR -> AKT1
# 85             0  PATH_FOUND                             EP300 -> TP63
# 91             0  PATH_FOUND              ERBB2 -> BRAF -> MTOR -> AKT
# 93             0  PATH_FOUND              ERBB2 -> EGFR -> ROS1 -> ERK
# 95             0  PATH_FOUND                     ERBB2 -> MET -> MAPK1
# 96             0  PATH_FOUND                     ERBB2 -> MET -> MAPK3
# 99             0  PATH_FOUND                     ERBB2 -> INSR -> ETS2
# 100            0  PATH_FOUND                             ERBB2 -> MDM2
# 101            0  PATH_FOUND              ERBB2 -> BRAF -> MTOR -> AKT
# 112            0  PATH_FOUND  Everolimus -> EIF4EBP1 -> MAPK1 -> MAPK3
# 113            0  PATH_FOUND                             FGFR1 -> AKT1
# 114            0  PATH_FOUND                             FGFR1 -> AKT3
# 115            0  PATH_FOUND                              FGFR1 -> ERK
# 120            0  PATH_FOUND              FLT3 -> FGFR1 -> MTOR -> AKT
# 124            0  PATH_FOUND                               GRB2 -> CBL
# 125            0  PATH_FOUND                   GRB2 -> MAP2K1 -> MAPK1
# 126            0  PATH_FOUND                   GRB2 -> MAP2K1 -> MAPK3
# 127            0  PATH_FOUND                   GRB2 -> MAP2K1 -> MAPK1
# 128            0  PATH_FOUND                   GRB2 -> MAP2K1 -> MAPK3
# 129            0  PATH_FOUND                   GRB2 -> MAP2K1 -> MAPK3
# 130            0  PATH_FOUND                    GRB2 -> PTPN11 -> HRAS
# 131            0  PATH_FOUND                       GRB2 -> ROS1 -> ERK
# 132            0  PATH_FOUND                       GRB2 -> ROS1 -> ERK
# 133            0  PATH_FOUND                   GRB2 -> MAP2K1 -> MAPK1
# 134            0  PATH_FOUND                   GRB2 -> MAP2K1 -> MAPK3
# 135            0  PATH_FOUND                              GRB2 -> RAF1
# 142            0  PATH_FOUND                     HRAS -> BRAF -> PLCE1
# 143            0  PATH_FOUND                      HRAS -> MYC -> ROCK1
# 145            0  PATH_FOUND                       INSR -> MTOR -> AKT
# 146            0  PATH_FOUND                  INSR -> MAPK1 -> RPS6KB1
# 147            0  PATH_FOUND                       INSR -> MTOR -> AKT
# 148            0  PATH_FOUND                             INSR -> MAPK3
# 149            0  PATH_FOUND                    INSR -> CBL -> RAPGEF1
# 151            0  PATH_FOUND                    IRS1 -> PTPN11 -> HRAS
# 152            0  PATH_FOUND                       IRS1 -> MTOR -> AKT
# 153            0  PATH_FOUND              IRS1 -> CASP3 -> ROS1 -> ERK
# 154            0  PATH_FOUND                    IRS1 -> PTPN11 -> HRAS
# 156            0  PATH_FOUND                            IRS1 -> PTPN11
# 167            0  PATH_FOUND                            KRAS -> RASSF2
# 170            0  PATH_FOUND                  MAP2K1 -> FOS -> RPS6KA2
# 181            0  PATH_FOUND                          MAPK1 -> RPS6KA2
# 183            0  PATH_FOUND                          MAPK1 -> RPS6KB2
# 192            0  PATH_FOUND                          MAPK3 -> RPS6KB2
# 197            0  PATH_FOUND                              MDM2 -> TP53
# 198            0  PATH_FOUND                    MERTK -> AKT1 -> MAPK1
# 199            0  PATH_FOUND          MERTK -> AKT1 -> MAP2K1 -> MAPK3
# 200            0  PATH_FOUND                     MERTK -> AKT1 -> RAF1
# 202            0  PATH_FOUND                       MET -> ROS1 -> RAC1
# 208            0  PATH_FOUND                               MYC -> CDK2
# 210            0  PATH_FOUND                      NRAS -> BRAF -> AKT1
# 217            0  PATH_FOUND                              PAK1 -> RAF1
# 219            0  PATH_FOUND                  PAK4 -> ARHGEF2 -> MAPK1
# 220            0  PATH_FOUND                     PAK4 -> RAF1 -> MAPK3
# 222            0  PATH_FOUND                  PDGFRB -> PTPN11 -> HRAS
# 223            0  PATH_FOUND             PDGFRB -> AKT1 -> MTOR -> AKT
# 224            0  PATH_FOUND                    PDGFRB -> MYC -> MAPK3
# 227            0  PATH_FOUND           PDGFR -> ARAF -> MAP2K1 -> HRAS
# 231            0  PATH_FOUND                               PIN1 -> JUN
# 232            0  PATH_FOUND                            PLXNB1 -> RHOA
# 234            0  PATH_FOUND                           PLXNB1 -> ERBB2
# 236            0  PATH_FOUND                              PTEN -> TP53
# 237            0  PATH_FOUND                              PTEN -> TP53
# 238            0  PATH_FOUND                           PTPN11 -> MAPK1
# 239            0  PATH_FOUND                           PTPN11 -> MAPK1
# 241            0  PATH_FOUND                     PTPN11 -> ROS1 -> ERK
# 242            0  PATH_FOUND                           PTPN11 -> MAPK1
# 243            0  PATH_FOUND                 PTPN11 -> MAP2K1 -> MAPK3
# 244            0  PATH_FOUND             PTPN11 -> ROS1 -> MTOR -> AKT
# 245            0  PATH_FOUND                    RAC1 -> PIK3R1 -> AKT3
# 247            0  PATH_FOUND                       RAC1 -> PAK2 -> JUN
# 248            0  PATH_FOUND                              RAC1 -> PAK2
# 249            0  PATH_FOUND                   RAC1 -> ROS1 -> RPS6KB1
# 251            0  PATH_FOUND                              RAC1 -> PAK1
# 253            0  PATH_FOUND            RAC2 -> ICMT -> DUSP1 -> MAPK1
# 254            0  PATH_FOUND                     RAC2 -> RHOA -> MAPK3
# 256            0  PATH_FOUND               RAF1 -> AKT1 -> ROS1 -> ERK
# 263            0  PATH_FOUND                           RASGRF1 -> HRAS
# 266            0  PATH_FOUND             RASSF1 -> KRAS -> ROS1 -> ERK
# 267            0  PATH_FOUND                RASSF1 -> ARHGEF2 -> MAPK1
# 268            0  PATH_FOUND                   RASSF1 -> RHOA -> MAPK3
# 269            0  PATH_FOUND                       RB1 -> ERBB2 -> E2F
# 270            0  PATH_FOUND                       RB1 -> ERBB2 -> E2F
# 271            0  PATH_FOUND                   RHEB -> RPS6KB1 -> MTOR
# 272            0  PATH_FOUND                           RHEB -> RPS6KB1
# 274            0  PATH_FOUND                  RHOA -> ARHGEF2 -> MAPK1
# 276            0  PATH_FOUND             RHOA -> KRAS -> BRAF -> PLCE1
# 277            0  PATH_FOUND                              RHOB -> AKT1
# 283            0  PATH_FOUND                   SHC1 -> MAP2K1 -> MAPK3
# 286            0  PATH_FOUND                      SHC1 -> SOS1 -> HRAS
# 287            0  PATH_FOUND                SHC1 -> ALK -> ROS1 -> ERK
# 290            0  PATH_FOUND                      SOS1 -> FGFR1 -> ERK
# 291            0  PATH_FOUND                      SOS1 -> MET -> MAPK1
# 292            0  PATH_FOUND                      SOS1 -> MET -> MAPK3
# 294            0  PATH_FOUND                       SRC -> EGFR -> AKT1
# 295            0  PATH_FOUND                SRC -> EGFR -> MTOR -> AKT
# 297            0  PATH_FOUND               SRC -> EGFR -> INSR -> ETS2
# 299            0  PATH_FOUND                     SRC -> EGFR -> MAP2K2
# 301            0  PATH_FOUND                        SRC -> EGFR -> MYC
# 302            0  PATH_FOUND                     SRC -> EGFR -> PDGFRB
# 303            0  PATH_FOUND               SRC -> EGFR -> ROS1 -> RAC1
# 309            0  PATH_FOUND                  Sirolimus -> MTOR -> AKT
# 311            0  PATH_FOUND                             TP53 -> CASP3
# 312            0  PATH_FOUND                      TSC2 -> RHEB -> BRAF
# 313            0  PATH_FOUND                             TSC2 -> MAPK1
# 314            0  PATH_FOUND                     TSC2 -> CDK2 -> MAPK3
# 315            0  PATH_FOUND                      TSC2 -> RHEB -> BRAF
# 316            0  PATH_FOUND                             TSC2 -> MAPK1
# 317            0  PATH_FOUND                     TSC2 -> CDK2 -> MAPK3
# 319            0  PATH_FOUND                      VAV1 -> EGFR -> PAK1
# 320            0  PATH_FOUND                      VAV1 -> RAC1 -> RAC2
# 323            0  PATH_FOUND                 ARHGAP35 -> GRB2 -> RASA1
# 328            0  PATH_FOUND                               CBL -> EGFR
# 329            0  PATH_FOUND                             CCND1 -> CDK4
# 330            0  PATH_FOUND                             CCND2 -> CDK4
# 334            0  PATH_FOUND                               E2F1 -> RB1
# 336            0  PATH_FOUND                             E2F1 -> TFDP1
# 337            0  PATH_FOUND                             E2F1 -> TFDP2
# 338            0  PATH_FOUND                             E2F2 -> TFDP1
# 339            0  PATH_FOUND                     E2F2 -> E2F1 -> TFDP2
# 340            0  PATH_FOUND                               E2F3 -> RB1
# 341            0  PATH_FOUND                             EGFR -> ERBB2
# 342            0  PATH_FOUND                              EGFR -> IRS1
# 343            0  PATH_FOUND                              EGFR -> SHC1
# 347            0  PATH_FOUND                           ERBB2 -> PTPN11
# 348            0  PATH_FOUND                             ERBB2 -> SHC1
# 350            0  PATH_FOUND                             FGFR2 -> PAK4
# 353            0  PATH_FOUND                                FOS -> JUN
# 354            0  PATH_FOUND                              GRB2 -> IRS1
# 355            0  PATH_FOUND                              GRB2 -> IRS2
# 357            0  PATH_FOUND                     GRB2 -> PLXNB1 -> MET
# 358            0  PATH_FOUND                              GRB2 -> PAK1
# 359            0  PATH_FOUND                              GRB2 -> SHC1
# 360            0  PATH_FOUND                              GRB2 -> SOS1
# 362            0  PATH_FOUND                              IRS1 -> MDM2
# 363            0  PATH_FOUND                            IRS1 -> PTPN11
# 364            0  PATH_FOUND                        JUN -> HRAS -> RB1
# 366            0  PATH_FOUND                            KRAS -> RASSF2
# 367            0  PATH_FOUND                            MAP2K1 -> RAF1
# 368            0  PATH_FOUND                              MDM2 -> TP53
# 371            0  PATH_FOUND                              PAK1 -> RAF1
# 372            0  PATH_FOUND                              PAK2 -> RAF1
# 373            0  PATH_FOUND                          PDGFRA -> PDGFRB
# 375            0  PATH_FOUND                          PIK3R1 -> PTPN11
# 376            0  PATH_FOUND                              PTEN -> TP53
# 377            0  PATH_FOUND                               RAF1 -> RB1
# 381            0  PATH_FOUND                              TP73 -> YAP1
# 382            0  PATH_FOUND                              TSC1 -> TSC2
# 383            0  PATH_FOUND                      AKT1 -> MDM2 -> TP53
# 390            0  PATH_FOUND                            BRCA1 -> BARD1
# 391            0  PATH_FOUND                             CASP3 -> MDM2
# 392            0  PATH_FOUND                               CBL -> EGFR
# 393            0  PATH_FOUND                            CDC25A -> CDK2
# 395            0  PATH_FOUND                      E2F -> CDK4 -> CCND1
# 396            0  PATH_FOUND                              EGFR -> TP53
# 405            0  PATH_FOUND                            MDM2 -> CDKN1A
# 406            0  PATH_FOUND                          MTOR -> EIF4EBP1
# 407            0  PATH_FOUND                              NF1 -> RASA1
# 408            0  PATH_FOUND                               NF1 -> TP53
# 409            0  PATH_FOUND                     PEA15 -> MAPK1 -> FOS
# 410            0  PATH_FOUND                   PTEN -> CDKN1A -> CCND3
# 411            0  PATH_FOUND                      PTEN -> CBLB -> GRB2
# 412            0  PATH_FOUND                              RAC2 -> RAC1
# 413            0  PATH_FOUND                   RAF1 -> SOS1 -> RASGRP1
# 414            0  PATH_FOUND                  RASSF1 -> BRCA1 -> CCND1
# 415            0  PATH_FOUND                               RB1 -> E2F1
# 416            0  PATH_FOUND                               RB1 -> E2F1
# 418            0  PATH_FOUND                       RB1 -> CASP3 -> JUN
# 419            0  PATH_FOUND                               RB1 -> E2F2
# 420            0  PATH_FOUND                               RB1 -> E2F2
# 421            0  PATH_FOUND                    ROCK2 -> CDC25A -> MYC
# 424            0  PATH_FOUND      Sirolimus -> MTOR -> CDKN1A -> CCND2
# 425            0  PATH_FOUND                         Sirolimus -> MTOR
# 426            0  PATH_FOUND                  Sirolimus -> MTOR -> MYC
# 428            0  PATH_FOUND       Sirolimus -> MTOR -> KRAS -> PIK3CG
# 431            0  PATH_FOUND                      AKT1 -> MDM2 -> E2F1
# 432            0  PATH_FOUND             AKT3 -> CASP3 -> JUN -> FOSL1
# 444            0  PATH_FOUND                            ARAF -> MAP2K1
# 445            0  PATH_FOUND                             BARD1 -> TP53
# 446            0  PATH_FOUND                               CBL -> EGFR
# 447            0  PATH_FOUND                                CBL -> MET
# 454            0  PATH_FOUND                        E2F -> PIN1 -> MYC
# 457            0  PATH_FOUND                               EGFR -> FOS
# 458            0  PATH_FOUND                              EGFR -> GRB2
# 459            0  PATH_FOUND                           EGFR -> RPS6KA3
# 460            0  PATH_FOUND                       EGFR -> MTOR -> AKT
# 461            0  PATH_FOUND                             EGFR -> MAPK1
# 462            0  PATH_FOUND                              EGFR -> GRB2
# 463            0  PATH_FOUND                            EGFR -> PTPN11
# 464            0  PATH_FOUND                              EGFR -> SHC1
# 467            0  PATH_FOUND                            ERBB2 -> CCND1
# 468            0  PATH_FOUND                   ERBB2 -> CDC25A -> CDK2
# 471            0  PATH_FOUND                     ERBB2 -> EGFR -> AKT2
# 472            0  PATH_FOUND                     ERBB2 -> MET -> MAPK3
# 473            0  PATH_FOUND                  ERBB2 -> IRS1 -> RPS6KB1
# 478            0  PATH_FOUND                            HRAS -> CDKN1A
# 479            0  PATH_FOUND                            HRAS -> CDKN1A
# 480            0  PATH_FOUND                     HRAS -> BRAF -> PLCE1
# 481            0  PATH_FOUND                   HRAS -> CDKN1A -> CCND1
# 483            0  PATH_FOUND                               INSR -> CBL
# 493            0  PATH_FOUND                            KRAS -> CDKN1A
# 497            0  PATH_FOUND                         MAPK1 -> EIF4EBP1
# 500            0  PATH_FOUND                              MDM2 -> TP53
# 501            0  PATH_FOUND                      MDM2 -> PAK4 -> RAF1
# 502            0  PATH_FOUND                              MDM2 -> TP53
# 504            0  PATH_FOUND                       MET -> TP53 -> MDM2
# 516            0  PATH_FOUND                     RAF1 -> EGFR -> RASA1
# 518            0  PATH_FOUND                             RAF1 -> SPRY2
# 521            0  PATH_FOUND                     RB1 -> KRAS -> RASSF2
# 523            0  PATH_FOUND                      SHC1 -> GRB2 -> RAC1
# 524            0  PATH_FOUND                              SOS1 -> RAC1
# 525            0  PATH_FOUND           SRC -> EGFR -> GRB2 -> ARHGAP35
# 526            0  PATH_FOUND                      SRC -> EGFR -> CCND1
# 528            0  PATH_FOUND                       SRC -> EGFR -> RAF1
# 529            0  PATH_FOUND                               SRC -> EGFR
# 530            0  PATH_FOUND                      SRC -> EGFR -> MAPK1
# 531            0  PATH_FOUND                      SRC -> EGFR -> MAPK3
# 532            0  PATH_FOUND                       SRC -> EGFR -> RAF1
# 534            0  PATH_FOUND               Sirolimus -> MTOR -> CDKN1A
# 535            0  PATH_FOUND         Sirolimus -> MTOR -> MAPK1 -> ERF
# 536            0  PATH_FOUND                 Sirolimus -> MTOR -> INSR
# 537            0  PATH_FOUND       Sirolimus -> MTOR -> EGFR -> PIK3R1
# 538            0  PATH_FOUND        Sirolimus -> MTOR -> BRCA1 -> TP73
# 539            0  PATH_FOUND                 Sirolimus -> MTOR -> TSC1
# 556            0  PATH_FOUND                              AKT1 -> RAF1
# 558            0  PATH_FOUND                              AKT1 -> TSC1
# 559            0  PATH_FOUND                              AKT1 -> TSC2
# 575            0  PATH_FOUND                              BRCA1 -> RB1
# 576            0  PATH_FOUND                             BRCA2 -> TP53
# 577            0  PATH_FOUND                             BRCA2 -> TP53
# 582            0  PATH_FOUND                               CBL -> EGFR
# 588            0  PATH_FOUND                           CDKN1A -> CASP3
# 589            0  PATH_FOUND                  CDKN1A -> CASP3 -> CASP8
# 590            0  PATH_FOUND                           CDKN1A -> CCND3
# 593            0  PATH_FOUND           DAB2IP -> KRAS -> MAPK1 -> ELK1
# 594            0  PATH_FOUND              DUSP1 -> EGFR -> ROS1 -> ERK
# 596            0  PATH_FOUND                 DUSP1 -> MAPK1 -> RPS6KB1
# 598            0  PATH_FOUND                            DUSP3 -> MAPK1
# 602            0  PATH_FOUND                  DUSP6 -> MAPK1 -> MAP2K1
# 604            0  PATH_FOUND                      ESR2 -> TP53 -> CDK2
# 608            0  PATH_FOUND                       HRAS -> MYC -> TSC2
# 611            0  PATH_FOUND                              IRS1 -> INSR
# 612            0  PATH_FOUND                              IRS1 -> INSR
# 613            0  PATH_FOUND                              IRS2 -> INSR
# 617            0  PATH_FOUND                              MDM2 -> TP53
# 618            0  PATH_FOUND                      MDM2 -> ERBB2 -> E2F
# 619            0  PATH_FOUND                               MTOR -> AKT
# 620            0  PATH_FOUND                              MTOR -> IRS1
# 622            0  PATH_FOUND                 NF1 -> ALK -> ROS1 -> ERK
# 624            0  PATH_FOUND                    NF1 -> PDGFRA -> MAPK1
# 625            0  PATH_FOUND                      NF1 -> KSR1 -> MAPK3
# 626            0  PATH_FOUND                        NF1 -> HRAS -> RB1
# 628            0  PATH_FOUND                     PEA15 -> MAPK1 -> FOS
# 630            0  PATH_FOUND                     PTEN -> PDPK1 -> AKT3
# 631            0  PATH_FOUND                       PTEN -> ROS1 -> ERK
# 632            0  PATH_FOUND                              PTEN -> IRS1
# 633            0  PATH_FOUND                             PTEN -> MAPK1
# 634            0  PATH_FOUND                   PTEN -> MAP2K1 -> MAPK3
# 635            0  PATH_FOUND                              PTEN -> MTOR
# 636            0  PATH_FOUND                             PTEN -> PDPK1
# 637            0  PATH_FOUND                      PTEN -> EGFR -> SHC1
# 638            0  PATH_FOUND                              PTEN -> AKT1
# 639            0  PATH_FOUND                       PTEN -> MTOR -> AKT
# 640            0  PATH_FOUND                   PTEN -> MAP2K1 -> MAPK3
# 643            0  PATH_FOUND                              RAC1 -> TP53
# 644            0  PATH_FOUND                             RAF1 -> MAPK1
# 645            0  PATH_FOUND                             RAF1 -> MAPK3
# 646            0  PATH_FOUND                               RB1 -> E2F1
# 647            0  PATH_FOUND                               RB1 -> E2F1
# 648            0  PATH_FOUND                               RB1 -> E2F1
# 649            0  PATH_FOUND                               RB1 -> E2F3
# 652            0  PATH_FOUND                               RB1 -> E2F1
# 653            0  PATH_FOUND                       RB1 -> ERBB2 -> E2F
# 654            0  PATH_FOUND                     RHEB -> BRAF -> MAPK3
# 655            0  PATH_FOUND                    ROCK1 -> MYC -> PPP1CA
# 658            0  PATH_FOUND                           RPS6KB1 -> IRS1
# 662            0  PATH_FOUND                      SOS1 -> NRAS -> ETS1
# 663            0  PATH_FOUND              SPRY1 -> GRB2 -> ROS1 -> ERK
# 671            0  PATH_FOUND              Sirolimus -> MTOR -> RPS6KB1
# 672            0  PATH_FOUND                         Sirolimus -> MTOR
# 674            0  PATH_FOUND                       TP53 -> MTOR -> AKT
# 681            0  PATH_FOUND                              TSC1 -> MTOR
# 682            0  PATH_FOUND                           TSC1 -> RPS6KB1
# 684            0  PATH_FOUND                              TSC1 -> MTOR
# 685            0  PATH_FOUND                              TSC2 -> MTOR
# 686            0  PATH_FOUND                           TSC2 -> RPS6KB1
# 687            0  PATH_FOUND                           TSC2 -> RPS6KB1
# 704            0  PATH_FOUND                               CDK4 -> RB1
# 705            0  PATH_FOUND                             CDKN1A -> RB1
# 707            0  PATH_FOUND                            DUSP1 -> MAPK1
# 708            0  PATH_FOUND                            DUSP1 -> MAPK3
# 709            0  PATH_FOUND                            DUSP6 -> MAPK1
# 710            0  PATH_FOUND             EGFR -> ROS1 -> RHOA -> ANXA1
# 713            0  PATH_FOUND                               EGFR -> CBL
# 714            0  PATH_FOUND                               EGFR -> CBL
# 715            0  PATH_FOUND                             EGFR -> ERBB2
# 716            0  PATH_FOUND                              EGFR -> INSR
# 717            0  PATH_FOUND                               EGFR -> MET
# 718            0  PATH_FOUND                               EGFR -> MYC
# 719            0  PATH_FOUND                              EGFR -> SHC1
# 720            0  PATH_FOUND                              EGFR -> SHC1
# 724            0  PATH_FOUND             EGFR -> ROS1 -> RHOA -> ANXA1
# 729            0  PATH_FOUND                              ERBB2 -> RB1
# 730            0  PATH_FOUND                             ERBB2 -> SHC1
# 731            0  PATH_FOUND                             ERBB2 -> SHC1
# 733            0  PATH_FOUND                     ERBB2 -> MET -> MAPK1
# 734            0  PATH_FOUND                     ERBB2 -> MET -> MAPK3
# 749            0  PATH_FOUND                              HRAS -> BRAF
# 751            0  PATH_FOUND                               HRAS -> JUN
# 752            0  PATH_FOUND                               HRAS -> MYC
# 756            0  PATH_FOUND                            INSR -> PTPN11
# 757            0  PATH_FOUND                              INSR -> SHC1
# 758            0  PATH_FOUND                              IRS1 -> AKT1
# 768            0  PATH_FOUND                               KRAS -> RB1
# 769            0  PATH_FOUND                  KRAS -> MAPK1 -> RPS6KB1
# 770            0  PATH_FOUND                     KRAS -> BRCA1 -> ETS1
# 773            0  PATH_FOUND                   MAP2K1 -> MAPK1 -> ELK1
# 775            0  PATH_FOUND                   MAP2K2 -> MAPK1 -> ELK1
# 777            0  PATH_FOUND                           MAP2K2 -> MAPK1
# 784            0  PATH_FOUND                            MAPK1 -> CCND1
# 785            0  PATH_FOUND                  MAPK1 -> BRCA1 -> CDC25A
# 786            0  PATH_FOUND                            MAPK1 -> DUSP1
# 789            0  PATH_FOUND                  MAPK3 -> BRCA1 -> CDC25A
# 794            0  PATH_FOUND                              MDM2 -> TP53
# 795            0  PATH_FOUND                               MET -> AKT1
# 796            0  PATH_FOUND                                MET -> CBL
# 798            0  PATH_FOUND                              MET -> MAPK1
# 799            0  PATH_FOUND                              MET -> MAPK3
# 800            0  PATH_FOUND                   MET -> MAPK1 -> RPS6KB1
# 801            0  PATH_FOUND                               MET -> SHC1
# 805            0  PATH_FOUND                          MTOR -> EIF4EBP1
# 807            0  PATH_FOUND                   MTOR -> KRAS -> RPS6KA1
# 808            0  PATH_FOUND                           MTOR -> RPS6KB1
# 810            0  PATH_FOUND                       NF1 -> TP53 -> MDM2
# 811            0  PATH_FOUND                        NF1 -> HRAS -> RB1
# 812            0  PATH_FOUND                   NRAS -> ROS1 -> RPS6KB1
# 813            0  PATH_FOUND                   NRAS -> ROS1 -> RPS6KB1
# 814            0  PATH_FOUND                   NRAS -> ROS1 -> RPS6KB1
# 815            0  PATH_FOUND             PDGFRB -> AKT1 -> MTOR -> AKT
# 816            0  PATH_FOUND                              PTEN -> AKT2
# 817            0  PATH_FOUND                       PTEN -> MTOR -> AKT
# 818            0  PATH_FOUND                              PTEN -> ETS2
# 819            0  PATH_FOUND                              PTEN -> IRS1
# 820            0  PATH_FOUND                      PTEN -> EGFR -> IRS2
# 821            0  PATH_FOUND                             PTEN -> MAPK1
# 822            0  PATH_FOUND                      PTEN -> EGFR -> SHC1
# 823            0  PATH_FOUND                       PTEN -> MTOR -> AKT
# 824            0  PATH_FOUND                              PTEN -> EGFR
# 826            0  PATH_FOUND                            PTPN11 -> INSR
# 827            0  PATH_FOUND                              RAC1 -> PAK1
# 828            0  PATH_FOUND                RAC1 -> ARHGAP35 -> PTPN11
# 830            0  PATH_FOUND                   RAC1 -> RALBP1 -> MAPK1
# 838            0  PATH_FOUND               RAF1 -> AKT1 -> MTOR -> AKT
# 839            0  PATH_FOUND            RASSF1 -> BRCA1 -> MTOR -> AKT
# 840            0  PATH_FOUND                RASSF1 -> ARHGEF2 -> MAPK1
# 841            0  PATH_FOUND                   RASSF1 -> RHOA -> MAPK3
# 842            0  PATH_FOUND                    RASSF1 -> KRAS -> RAF1
# 843            0  PATH_FOUND                              ROCK1 -> MYC
# 850            0  PATH_FOUND             SRC -> EGFR -> ARAF -> MAP2K1
# 851            0  PATH_FOUND                     SRC -> EGFR -> MAP2K2
# 852            0  PATH_FOUND                      SRC -> EGFR -> MAPK3
# 853            0  PATH_FOUND              SRC -> EGFR -> ARAF -> PDGFR
# 855            0  PATH_FOUND                SRC -> EGFR -> MTOR -> AKT
# 856            0  PATH_FOUND                      SRC -> EGFR -> GRB10
# 857            0  PATH_FOUND                      SRC -> EGFR -> MAPK1
# 859            0  PATH_FOUND                  Sirolimus -> MTOR -> AKT
# 860            0  PATH_FOUND             Sirolimus -> MTOR -> EIF4EBP1
# 861            0  PATH_FOUND              Sirolimus -> MTOR -> RPS6KB1
# 862            0  PATH_FOUND              Sirolimus -> MTOR -> RPS6KB1
# 865            0  PATH_FOUND                 TP53 -> APAF1 -> EIF4EBP1
# 866            0  PATH_FOUND                               VAV1 -> CBL

# %% [markdown]
# So approximately half of the tests that fail in the ModelChecker pass in the directed graph. Inspection of the specific cases highlights a few recurring scenarios:
